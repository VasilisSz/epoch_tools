# %% [markdown]
# # Tutorial 3
# ### Interpreting clusters

# %%
import epoch_tools as et
import mne
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
epochs = et.Epochs.load_gz(r"test_data\tutorial2_Epochs.gz")
# Out:
# Reading C:\Users\basil\AppData\Local\Temp\tmpr0tn2mjk-mne-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...    4999.45 ms
#         0 CTF compensation matrices available
# Adding metadata with 257 columns
# 152 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
# Instantiate the ClusterInterpreter
ci = et.ClusterInterpreter(epochs, model_type='random_forest', random_state=42)

# %%
ci.epochs.labels.shape, ci.epochs.metadata.shape
# Out:
# ((152,), (152, 257))

# %%
ci.plot_feature_values(figsize=(10, 10))
# Out:
# <Axes: title={'center': 'Feature Values per Cluster'}, xlabel='Feature', ylabel='Scaled Feature Value'>

# %%
ci.plot_transition_matrix()

# %%
ci.plot_epoch_signal(nstd=3)

# %%
ci.plot_feature_density()

# %%
ci.plot_feature_hierarchy(figsize=(10, 3))

# %%
ci.fit()
ci.plot_feature_importances_global()
# Out:
# Model trained on 121 samples. Held out 31 for testing.
# Accuracy: 0.967741935483871

# %%
ci.plot_shap_summary()

# %%
ci.plot_shap_decision_plot()
