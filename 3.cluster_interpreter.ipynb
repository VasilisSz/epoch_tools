# %% [markdown]
# # Tutorial 3
# ### Interpreting clusters

# %%
import epoch_tools as et
import mne
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
epochs = et.Epochs.load_epochs("tutorials/test_data/tutorial2_Epochs-taini-epo.pkl")
# Out:
# Reading d:\RA\custom_libs\epoch_tools\tutorials\test_data\tutorial2_Epochs-mne-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...    4999.45 ms
#         0 CTF compensation matrices available
# Adding metadata with 257 columns
# 152 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
# Instantiate the ClusterInterpreter
ci = et.ClusterInterpreter(epochs, model_type='random_forest', random_state=42)

# %%
ci.plot_epoch_signal(nstd=3)

# %%
ci.plot_epoch_signal(n_epochs=5, channels_to_plot=['OFC_L', 'EMG_L'], nstd=5)

# %%
ci.plot_feature_values()

# %%
ci.plot_feature_density()

# %%
ci.plot_feature_hierarchy()

# %%
ci.fit()
ci.plot_feature_importances_global()
# Out:
# Model trained on 121 samples. Held out 31 for testing.

# %%
ci.plot_shap_summary()

# %%
ci.plot_shap_decision_plot()
